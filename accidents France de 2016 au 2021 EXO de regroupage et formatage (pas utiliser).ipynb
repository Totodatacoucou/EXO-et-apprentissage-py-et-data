# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

# %% [markdown]
# # regroupment les 4 fichiers de chaque année depuis 2016 au 2021

# %%
usagers_2016 = pd.read_csv("usagers_2016.csv",delimiter=",")
vehicules_2016 = pd.read_csv("vehicules_2016.csv",delimiter=",")
lieux_2016 = pd.read_csv("lieux_2016.csv", delimiter=",")
caracteristiques_2016 = pd.read_csv("caracteristiques_2016.csv",delimiter=",")
# Out:
# C:\Users\arnoa\AppData\Local\Temp\ipykernel_17916\819307994.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   lieux_2016 = pd.read_csv("lieux_2016.csv", delimiter=",")
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17916\819307994.py in <module>
#       2 vehicules_2016 = pd.read_csv("vehicules_2016.csv",delimiter=",")
#       3 lieux_2016 = pd.read_csv("lieux_2016.csv", delimiter=",")
# ----> 4 caracteristiques_2016 = pd.read_csv("caracteristiques_2016.csv",delimiter=",")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# # Nous détectons un problème pour 'lire' les fichiers xls ou csv, problème de séparateur de colonne ';' ou ',', ou les encodages, aussi la différence de la quantité des colonnes, et l'ordre de placement des colonnes, aussi le format des données par colonnes est différent dans les fichiers d'années différentes... donc tous cela faut prendre en consideration dans le processus de regroupement de plusueurs data sets

# %%
usagers_2016_ = pd.read_csv("usagers_2016.csv",delimiter=",")

# %%
usagers_2020 = pd.read_csv("usagers-2020.csv",delimiter=";")
usagers_2019 = pd.read_csv("usagers-2019.csv",delimiter=";")
usagers_2018 = pd.read_csv("usagers-2018.csv",delimiter=";")
usagers_2017 = pd.read_csv("usagers-2017.csv",delimiter=";")
usagers_2016 = pd.read_csv("usagers_2016.csv",delimiter=";")

# %%
usagers_2016_
# Out:
#              Num_Acc  place  catu  grav  sexe  trajet  secu  locp  actp  \
# 0       201600000001    1.0     1     1     2     0.0  11.0   0.0   0.0
# 1       201600000001    1.0     1     3     1     9.0  21.0   0.0   0.0
# 2       201600000002    1.0     1     3     1     5.0  11.0   0.0   0.0
# 3       201600000002    2.0     2     3     1     0.0  11.0   0.0   0.0
# 4       201600000002    3.0     2     3     2     0.0  11.0   0.0   0.0
# ...              ...    ...   ...   ...   ...     ...   ...   ...   ...
# 133417  201600059431    1.0     1     4     1     0.0  21.0   0.0   0.0
# 133418  201600059431    1.0     1     4     1     0.0  21.0   0.0   0.0
# 133419  201600059432    1.0     1     4     1     3.0  21.0   0.0   0.0
# 133420  201600059432    2.0     2     4     1     0.0  21.0   0.0   0.0
# 133421  201600059432    1.0     1     1     1     0.0  11.0   0.0   0.0
#
#         etatp  an_nais num_veh
# 0         0.0   1983.0     B02
# 1         0.0   2001.0     A01
# ...

# %%
usagers_2016
# Out:
#        Num_Acc,place,catu,grav,sexe,trajet,secu,locp,actp,etatp,an_nais,num_veh
# 0                201600000001,1,1,1,2,0,11,0,0,0,1983,B02
# 1                201600000001,1,1,3,1,9,21,0,0,0,2001,A01
# 2                201600000002,1,1,3,1,5,11,0,0,0,1960,A01
# 3                201600000002,2,2,3,1,0,11,0,0,0,2000,A01
# 4                201600000002,3,2,3,2,0,11,0,0,0,1962,A01
# ...                                                   ...
# 133417           201600059431,1,1,4,1,0,21,0,0,0,1994,A01
# 133418           201600059431,1,1,4,1,0,21,0,0,0,1990,B01
# 133419           201600059432,1,1,4,1,3,21,0,0,0,1967,A01
# 133420           201600059432,2,2,4,1,0,21,0,0,0,1967,A01
# 133421           201600059432,1,1,1,1,0,11,0,0,0,1981,B01
#
# [133422 rows x 1 columns]

# %%
usagers_2017
# Out:
#        Num_Acc,place,catu,grav,sexe,trajet,secu,locp,actp,etatp,an_nais,num_veh
# 0                201700000001,1,1,3,1,9,13,0,0,0,1968,B01
# 1                201700000001,2,2,3,2,9,11,0,0,0,1973,B01
# 2                201700000001,1,1,3,1,1,13,0,0,0,1967,A01
# 3                201700000002,1,1,1,1,0,11,0,0,0,1953,A01
# 4                201700000002,1,1,3,1,5,22,0,0,0,1960,B01
# ...                                                   ...
# 136016           201700060699,1,1,1,2,9,11,0,0,0,1974,B01
# 136017           201700060700,1,1,1,2,9,11,0,0,0,1987,A01
# 136018           201700060700,1,1,4,1,9,21,0,0,0,1991,B01
# 136019           201700060700,2,2,4,2,9,21,0,0,0,1990,B01
# 136020           201700060701,1,1,4,1,1,21,0,0,0,1992,A01
#
# [136021 rows x 1 columns]

# %%
usagers_2018
# Out:
#        Num_Acc,place,catu,grav,sexe,trajet,secu,locp,actp,etatp,an_nais,num_veh
# 0                201800000001,1,1,3,1,0,11,0,0,0,1928,B01
# 1                201800000001,1,1,1,1,5,11,0,0,0,1960,A01
# 2                201800000002,1,1,1,1,0,11,0,0,0,1947,A01
# 3                  201800000002,,3,4,1,0,2,2,3,1,1959,A01
# 4                201800000003,1,1,3,1,5,21,0,0,0,1987,A01
# ...                                                   ...
# 130164             201800057781,,3,4,1,9,3,4,3,1,1975,A01
# 130165              201800057782,1,1,4,2,9,11,,,,1993,A01
# 130166              201800057782,1,1,4,1,9,21,,,,1974,B01
# 130167              201800057783,1,1,4,1,9,11,,,,1973,B01
# 130168              201800057783,1,1,4,2,9,11,,,,1990,A01
#
# [130169 rows x 1 columns]

# %%
usagers_2019
# Out:
#              Num_Acc  id_vehicule num_veh  place  catu  grav  sexe  an_nais  \
# 0       201900000001  138 306 524     B01      2     2     4     2     2002
# 1       201900000001  138 306 524     B01      1     1     4     2     1993
# 2       201900000001  138 306 525     A01      1     1     1     1     1959
# 3       201900000002  138 306 523     A01      1     1     4     2     1994
# 4       201900000003  138 306 520     A01      1     1     1     1     1996
# ...              ...          ...     ...    ...   ...   ...   ...      ...
# 132972  201900058837  137 982 135     C01      1     1     4     2     1988
# 132973  201900058838  137 982 132     A01      1     1     4     1     1998
# 132974  201900058839  137 982 131     A01      1     1     3     1     1979
# 132975  201900058840  137 982 129     B01      1     1     4     1     1974
# 132976  201900058840  137 982 130     A01      1     1     1     1     1971
#
#         trajet  secu1  secu2  secu3  locp actp  etatp
# ...

# %%
usagers_2020
# Out:
#              Num_Acc  id_vehicule num_veh  place  catu  grav  sexe  an_nais  \
# 0       202000000001  154 742 274     B01      1     1     1     1     1983
# 1       202000000001  154 742 275     A01      1     1     3     1     1982
# 2       202000000002  154 742 273     A01      1     1     1     1     1997
# 3       202000000002  154 742 273     A01     10     3     4     1     1967
# 4       202000000003  154 742 271     B01      1     1     1     1     1985
# ...              ...          ...     ...    ...   ...   ...   ...      ...
# 105290  202000047743  154 658 351     B01      4     2     4     1     2011
# 105291  202000047743  154 658 351     B01      1     1     4     2     1981
# 105292  202000047743  154 658 352     A01      1     1     4     1     1998
# 105293  202000047744  154 658 350     A01      1     1     1     1     1967
# 105294  202000047744  154 658 350     A01     10     3     4     2     1963
#
#         trajet  secu1  secu2  secu3  locp actp  etatp
# ...

# %%
caracteristiques_2016 = pd.read_csv("caracteristiques_2016.csv",delimiter=",", encoding = "ISO-8859-1")
caracteristiques_2017 = pd.read_csv("caracteristiques-2017.csv",delimiter=",", encoding = "ISO-8859-1")
caracteristiques_2018 = pd.read_csv("caracteristiques-2018.csv",delimiter=",", encoding = "ISO-8859-1")
caracteristiques_2019 = pd.read_csv("caracteristiques-2019.csv",delimiter=";")
caracteristiques_2020 = pd.read_csv("caracteristiques-2020.csv",delimiter=";")
carcteristiques_2021 =pd.read_csv("carcteristiques-2021.csv",delimiter=";")

# %%
caracteristiques_2016 = pd.read_csv("caracteristiques_2016.csv",delimiter=",", encoding = "ISO-8859-1")

# %%
caracteristiques_2017 = pd.read_csv("caracteristiques-2017.csv",delimiter=",", encoding = "ISO-8859-1")

# %%
caracteristiques_2016
# Out:
#             Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# 0      201600000001  16     2     1  1445    1    2    1    8  3.0    5
# 1      201600000002  16     3    16  1800    1    2    6    1  6.0    5
# 2      201600000003  16     7    13  1900    1    1    1    1  6.0   11
# 3      201600000004  16     8    15  1930    2    2    1    7  3.0  477
# 4      201600000005  16    12    23  1100    1    2    3    1  3.0   11
# ...             ...  ..   ...   ...   ...  ...  ...  ...  ...  ...  ...
# 59427  201600059428  16    12     1  1201    1    2    1    1  6.0  611
# 59428  201600059429  16    12     3  2215    1    2    1    1  7.0  611
# 59429  201600059430  16    12     5  1710    1    2    1    1  3.0  611
# 59430  201600059431  16    12     6  1005    1    2    3    1  3.0  611
# 59431  201600059432  16    12    24   635    1    2    6    1  3.0  611
#
#                             adr  gps  lat  long  dep
# ...

# %%
caracteristiques_2017
# Out:
#             Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# 0      201700000001  17     1    11  1820    5    2    1  1.0  1.0  477
# 1      201700000002  17     2    13  1630    1    2    3  1.0  3.0    5
# 2      201700000003  17     3     7  1150    1    2    9  1.0  5.0   52
# 3      201700000004  17     4    22  1300    1    2    1  1.0  6.0    5
# 4      201700000005  17     5    20  1230    1    2    1  1.0  2.0   11
# ...             ...  ..   ...   ...   ...  ...  ...  ...  ...  ...  ...
# 60696  201700060697  17    11    19  1030    1    2    1  1.0  6.0  611
# 60697  201700060698  17    11    25   624    1    1    6  1.0  7.0  611
# 60698  201700060699  17    11    26  1745    2    2    1  1.0  3.0  611
# 60699  201700060700  17    11    28  1405    1    2    1  1.0  3.0  611
# 60700  201700060701  17    11    30  1939    3    2    1  1.0  6.0  611
#
#                             adr gps        lat       long  dep
# ...

# %% [markdown]
# # voir caracterustique de la ligne precise 60696 de la data fram

# %%
caracteristiques_2017.iloc[60696]
# Out:
# Num_Acc                201700060697
# an                               17
# mois                             11
# jour                             19
# hrmn                           1030
# lum                               1
# agg                               2
# int                               1
# atm                             1.0
# col                             6.0
# com                             611
# adr        1, tsoundzou-Baraka (rue
# gps                               Y
# lat                       1280703.0
# long                      4520703.0
# dep                             976
# Name: 60696, dtype: object

# %%
print(caracteristiques_2017['adr'])
# Out:
# 0                   rue nationale
# 1                5 rue sonneville
# 2                rue Jules Guesde
# 3               46 rue Sonneville
# 4              Rue roger salengro
#                    ...
# 60696    1, tsoundzou-Baraka (rue
# 60697    1, mamoudzou centre-Adri
# 60698    1, tsoundzou-Abdallah So
# 60699     1, kaweni-Kaweni nord (
# 60700       tsoundzou-Stara (rue)
# Name: adr, Length: 60701, dtype: object

# %% [markdown]
# # voir un élément dans le colonne d'adresse et une ligne precise

# %%
print(caracteristiques_2017.loc[60696, 'adr'])
# Out:
# 1, tsoundzou-Baraka (rue

# %%
caracteristiques_2018
# Out:
#             Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# 0      201800000001  18     1    24  1505    1    1    4  1.0  1.0    5
# 1      201800000002  18     2    12  1015    1    2    7  7.0  7.0   11
# 2      201800000003  18     3     4  1135    1    2    3  1.0  7.0  477
# 3      201800000004  18     5     5  1735    1    2    1  7.0  3.0   52
# 4      201800000005  18     6    26  1605    1    2    1  1.0  3.0  477
# ...             ...  ..   ...   ...   ...  ...  ...  ...  ...  ...  ...
# 57778  201800057779  18    12    15  1050    1    2    1  1.0  6.0  611
# 57779  201800057780  18    12    16   610    2    2    1  1.0  3.0  611
# 57780  201800057781  18    12    22  2150    5    2    1  1.0  6.0  611
# 57781  201800057782  18    12    23  1945    5    2    1  1.0  1.0  611
# 57782  201800057783  18    12    28  1425    1    2    1  1.0  1.0  611
#
#                             adr gps        lat       long  dep
# ...

# %% [markdown]
# # On cherche un élément presis dans tout ma data frame. ici il n'y a pas de ce élément '1, tsoundzou-Baraka (rue'

# %%
result = caracteristiques_2018.loc[caracteristiques_2018['adr'] == '1, tsoundzou-Baraka (rue']
print(result)
# Out:
# Empty DataFrame
# Columns: [Num_Acc, an, mois, jour, hrmn, lum, agg, int, atm, col, com, adr, gps, lat, long, dep]
# Index: []

# %%
caracteristiques_2019
# Out:
#             Num_Acc  jour  mois    an   hrmn  lum dep    com  agg  int  atm  \
# 0      201900000001    30    11  2019  01:30    4  93  93053    1    1    1
# 1      201900000002    30    11  2019  02:50    3  93  93066    1    1    1
# 2      201900000003    28    11  2019  15:15    1  92  92036    1    1    1
# 3      201900000004    30    11  2019  20:20    5  94  94069    1    1    1
# 4      201900000005    30    11  2019  04:00    3  94  94028    1    1    1
# ...             ...   ...   ...   ...    ...  ...  ..    ...  ...  ...  ...
# 58835  201900058836    30    11  2019  09:00    1  69  69288    1    1    5
# 58836  201900058837    27    11  2019  07:50    1  67  67482    1    1    8
# 58837  201900058838    30    11  2019  02:41    4  94  94021    1    1    1
# 58838  201900058839    30    11  2019  15:20    1  78  78640    1    1    1
# 58839  201900058840    29    11  2019  20:50    3  92  92047    1    1    1
#
#        col                    adr         lat       long
# ...

# %% [markdown]
# # On cherche un élément dans la data frame en utilisant une méthode map et une fonction "lambda" :

# %%
# Charger la dataframe 'caracteristiques_2018'
#caracteristiques_2018 = pd.read_csv('chemin_vers_fichier/caracteristiques_2018.csv', encoding='utf-8')

# Chercher l'élément 'Margo'
result = caracteristiques_2018.applymap(lambda x: x == 'Margo')

# Afficher les lignes qui contiennent l'élément 'Margo'
print(result.any(axis=1))
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 57778    False
# 57779    False
# 57780    False
# 57781    False
# 57782    False
# Length: 57783, dtype: bool

# %%
caracteristiques_2020
# Out:
#             Num_Acc  jour  mois    an   hrmn  lum dep    com  agg  int  atm  \
# 0      202000000001     7     3  2020  16:55    1  91  91657    2    3    1
# 1      202000000002     7     3  2020  08:35    2  91  91657    2    9    7
# 2      202000000003     7     3  2020  13:30    1  91  91174    2    2    1
# 3      202000000004     7     3  2020  18:50    5  91  91215    2    1    1
# 4      202000000005     7     3  2020  11:00    1  77  77181    1    6    1
# ...             ...   ...   ...   ...    ...  ...  ..    ...  ...  ...  ...
# 47739  202000047740    30    11  2020  07:50    1  13  13028    2    1    1
# 47740  202000047741    30    11  2020  17:00    2  06  06083    2    1    9
# 47741  202000047742     1    12  2020  10:00    1  06  06069    2    1    1
# 47742  202000047743    28    11  2020  11:45    1  05  05061    1    1    1
# 47743  202000047744    18    11  2020  17:44    4  05  05061    2    1    1
#
# ...

# %%
carcteristiques_2021
# Out:
#             Num_Acc  jour  mois    an   hrmn  lum dep    com  agg  int  atm  \
# 0      202100000001    30    11  2021  07:32    2  30  30319    1    1    1
# 1      202100000002    25     9  2021  14:20    1  51  51544    1    3    1
# 2      202100000003    15     7  2021  07:55    1  85  85048    2    1    7
# 3      202100000004    27     3  2021  19:45    5  93  93005    2    2    3
# 4      202100000005    25     2  2021  07:20    5  76  76429    2    1    1
# ...             ...   ...   ...   ...    ...  ...  ..    ...  ...  ...  ...
# 56513  202100056514     1     1  2021  06:10    3  33  33021    1    1    5
# 56514  202100056515     1     1  2021  10:20    1  38  38405    1    1    2
# 56515  202100056516     1     1  2021  18:00    3  26  26064    1    1    2
# 56516  202100056517     1     1  2021  10:55    1  33  33003    1    2    1
# 56517  202100056518     2     1  2021  18:00    3  78  78423    1    1    3
#
# ...

# %%
# Out:
#             Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# 0      201700000001  17     1    11  1820    5    2    1  1.0  1.0  477
# 1      201700000002  17     2    13  1630    1    2    3  1.0  3.0    5
# 2      201700000003  17     3     7  1150    1    2    9  1.0  5.0   52
# 3      201700000004  17     4    22  1300    1    2    1  1.0  6.0    5
# 4      201700000005  17     5    20  1230    1    2    1  1.0  2.0   11
# ...             ...  ..   ...   ...   ...  ...  ...  ...  ...  ...  ...
# 60696  201700060697  17    11    19  1030    1    2    1  1.0  6.0  611
# 60697  201700060698  17    11    25   624    1    1    6  1.0  7.0  611
# 60698  201700060699  17    11    26  1745    2    2    1  1.0  3.0  611
# 60699  201700060700  17    11    28  1405    1    2    1  1.0  3.0  611
# 60700  201700060701  17    11    30  1939    3    2    1  1.0  6.0  611
#
#                             adr gps        lat       long  dep
# ...

# %%
usagers = pd.read_csv("usagers_2016.csv",delimiter=";")
vehicules = pd.read_csv("vehicules-2021.csv",delimiter=";")
lieux = pd.read_csv("lieux-2021.csv", delimiter=";")
caracteristiques = pd.read_csv("carcteristiques-2021.csv",delimiter=";")

# %%
usagers = pd.read_csv("usagers_2016.csv",delimiter=";")
vehicules = pd.read_csv("vehicules-2021.csv",delimiter=";")
lieux = pd.read_csv("lieux-2021.csv", delimiter=";")
caracteristiques = pd.read_csv("carcteristiques-2021.csv",delimiter=";")

# %%
usagers = pd.read_csv("usagers_2016.csv",delimiter=";")
vehicules = pd.read_csv("vehicules-2021.csv",delimiter=";")
lieux = pd.read_csv("lieux-2021.csv", delimiter=";")
caracteristiques = pd.read_csv("carcteristiques-2021.csv",delimiter=";")

# %%
df_2016= 
df_2017=
df_2018=
df_2019=
df_2020=
df_2021=

# %% [markdown]
# # J'ai 4 fichiers csv: usagers, vehicules, lieux, caracteristiques, par chaque année 2016-2021 donc 24 fichirs au total, à present, pour gagner du temps, je vais passer en aplication excel ou libre office calc pour traiter=formater ces fichiers, il y a surment des methodes automatisées pour regroupper pluseurs fichiser des formats differants dans un seul evitant des eurreures... mais je ne connait pas encore ces methodes s'ils existent. Et donc traiter les 20 fichiers un par un me prendra bcp trop du temps .
